# %%
x = 10

if x == 10:
    pass    
    
print("10입니다.")
# Out:
# 10입니다.

# %%
x = 10

if x == 10:
    print("x에 들어있는 숫자는")
    print("10 입니다.")
# Out:
# x에 들어있는 숫자는
# 10 입니다.

# %%
# 중첩 if 조건문 사용하기
# x = 15
x = 20

if x >= 10:
    print("10 이상입니다.")

    if x == 10:
        print("10 입니다.")

    if x == 20:
        print("20 입니다.")
# Out:
# 10 이상입니다.
# 20 입니다.

# %%
x = int(input("숫자를 입력하세요: "))

if x == 10:
        print("10 입니다.")

if x == 20:
        print("20 입니다.")
# Out:
# 10 입니다.

# %%
# 연습문제 13.6

x = 5
if x != 10:
    print("OK")
# Out:
# OK

# %%
# 심사문제 13.7

# 27000
# Cash3000

price = int(input())
coupon = input()

dis = int(coupon[4:])

print(price - dis)
# Out:
# 24000
