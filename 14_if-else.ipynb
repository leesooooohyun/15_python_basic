# %%
# else 사용하기
x = 5

if x == 10: print("10 입니다.")
else: print("10이 아닙니다.")
# Out:
# 10이 아닙니다.

# %%
x = 5

if x == 10:
    print("10 입니다.")
else:
    print("x에 들어있는 숫자는")
    print("10이 아닙니다.")
# Out:
# x에 들어있는 숫자는
# 10이 아닙니다.

# %%
# if 조건문의 동작 방식 알아보기

if True:
    print("참")
else:
    print("거짓")

if False:
    print("참")
else:
    print("거짓")

bool(None)
# Out:
# 참
# 거짓
# False

# %%
if " ": # 공백은 참, 빈 문자열은 거짓
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
if []:
    print("참")
else:
    print("거짓")
# Out:
# 거짓

# %%
x = 10
y = 20

if x == 10 and y == 20:
    print('참')
else:
    print("거짓")
# Out:
# 참

# %%
# 10 이상이고 20 미만인 숫자는 참
x = int(input("숫자를 입력하세요 : "))

if x >= 10 and x < 20: # 10 <= x < 20
    print("참")
else:
    print("거짓")
# Out:
# 참

# %%
# 퀴즈 14.5
c

b d

True

b e

a

# %%
if not '':
    print(True)
else:
    print(False)
# Out:
# True

# %%
# 연습문제 14.6

written_test = 75
coding_test = True

if written_test >= 80 and coding_test == True:
    print('합격')
else:
    print('불합격')
# Out:
# 불합격

# %%
# 심사문제 14.7

kor, eng, mat, sci = map(int, input().split())

avg = (kor + eng + mat + sci) / 4

if 0 <= kor <= 100 and 0 <= eng <= 100 and 0 <= mat <= 100 and 0 <= sci <= 100:
    if avg >= 80:
        print("합격")
    else:
        print("불합격")
else:
    print("잘못된 점수")
# Out:
# 잘못된 점수
