# %%
# while 조건문:
#     반복할 코드

i = 0

while i < 100:
    print("hello world")
    i += 1

# %%
# 초기값을 1부터 시작하기
i = 1
while i <= 100:
    print("hello world")
    i += 1

# %%
# 초기값을 감소시키기

i = 100

while i > 0:
    print("hello world", i)
    i -= 1

# %%
# 입력한 횟수대로 반복하기
count = int(input("반복할 횟수를 입력하세요 : "))

i = 0
while i < count:
    print("hello world", i)
    i += 1

# %%
import random

# %%
random.random()

# %%
random.randint(1, 10)

# %%
import random

i = 0
while i != 3:
    i = random.randint(1, 10)
    print(i)

# %%
# 퀴즈 17.4
b c

d

c

b e

# %%
# 연습문제 17.5

i = 2
j = 5

while i < 33 and j > 0:
    print(i, j)
    i *= 2
    j -= 1
# Out:
# 2 5
# 4 4
# 8 3
# 16 2
# 32 1

# %%
# 심사문제 17.6

fee = int(input())

while fee >= 1350:
    fee -= 1350
    print(fee)
# Out:
# 8650
# 7300
# 5950
# 4600
# 3250
# 1900
# 550
